# %%
# Import dependencies
import random
import numpy as np
from citipy import citipy 
from config import weather_api_key
import pandas as pd
import requests
import time
from datetime import datetime

# %%
# Create a new set of 2,000 random latitudes and longitude
lats = np.random.uniform(-90.000, 90.000, size = 2000)
lngs = np.random.uniform(-180.000, 180.000, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 793

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+ weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dd5938d8a2013955d29dd41eee57df29

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_weather = city_weather["weather"][0]['description'] 
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "City Description": city_current_weather})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | coquimbo
# Processing Record 2 of Set 1 | dickinson
# Processing Record 3 of Set 1 | naze
# Processing Record 4 of Set 1 | porvoo
# Processing Record 5 of Set 1 | oktyabrskiy
# Processing Record 6 of Set 1 | cidreira
# Processing Record 7 of Set 1 | hithadhoo
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | san patricio
# Processing Record 10 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 1 | port blair
# Processing Record 12 of Set 1 | sabang
# Processing Record 13 of Set 1 | viransehir
# Processing Record 14 of Set 1 | caxito
# Processing Record 15 of Set 1 | avarua
# Processing Record 16 of Set 1 | tiruvottiyur
# City not found. Skipping...
# Processing Record 17 of Set 1 | ukiah
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | larap
# Processing Record 21 of Set 1 | acari
# Processing Record 22 of Set 1 | hamilton
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | agropoli
# Processing Record 25 of Set 1 | meinerzhagen
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | enshi
# Processing Record 28 of Set 1 | andenes
# Processing Record 29 of Set 1 | bredasdorp
# Processing Record 30 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 1 | kavieng
# Processing Record 32 of Set 1 | alofi
# Processing Record 33 of Set 1 | tuktoyaktuk
# Processing Record 34 of Set 1 | janakpur
# Processing Record 35 of Set 1 | huancavelica
# Processing Record 36 of Set 1 | palencia
# Processing Record 37 of Set 1 | atuona
# Processing Record 38 of Set 1 | dalby
# Processing Record 39 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 40 of Set 1 | casa grande
# Processing Record 41 of Set 1 | hobart
# Processing Record 42 of Set 1 | itarema
# Processing Record 43 of Set 1 | nhlangano
# Processing Record 44 of Set 1 | talnakh
# Processing Record 45 of Set 1 | saint george
# Processing Record 46 of Set 1 | kaitangata
# Processing Record 47 of Set 1 | zyryanka
# Processing Record 48 of Set 1 | weyburn
# Processing Record 49 of Set 1 | warmbad
# Processing Record 50 of Set 1 | kismayo
# Processing Record 1 of Set 2 | babanusah
# City not found. Skipping...
# Processing Record 2 of Set 2 | rikitea
# Processing Record 3 of Set 2 | ushuaia
# Processing Record 4 of Set 2 | gazli
# Processing Record 5 of Set 2 | margate
# Processing Record 6 of Set 2 | mount isa
# Processing Record 7 of Set 2 | sitka
# Processing Record 8 of Set 2 | tsabong
# Processing Record 9 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 10 of Set 2 | zadar
# Processing Record 11 of Set 2 | pedernales
# Processing Record 12 of Set 2 | manta
# Processing Record 13 of Set 2 | nikel
# Processing Record 14 of Set 2 | saldanha
# Processing Record 15 of Set 2 | ostrovnoy
# Processing Record 16 of Set 2 | hilo
# Processing Record 17 of Set 2 | brighton
# Processing Record 18 of Set 2 | esperance
# Processing Record 19 of Set 2 | shelburne
# Processing Record 20 of Set 2 | barrow
# Processing Record 21 of Set 2 | capao da canoa
# Processing Record 22 of Set 2 | yokadouma
# Processing Record 23 of Set 2 | castro
# Processing Record 24 of Set 2 | tautira
# Processing Record 25 of Set 2 | yellowknife
# Processing Record 26 of Set 2 | zachagansk
# City not found. Skipping...
# Processing Record 27 of Set 2 | broken hill
# Processing Record 28 of Set 2 | qaanaaq
# Processing Record 29 of Set 2 | nuuk
# Processing Record 30 of Set 2 | dingle
# Processing Record 31 of Set 2 | mount gambier
# Processing Record 32 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 2 | lasa
# Processing Record 34 of Set 2 | ribeira grande
# Processing Record 35 of Set 2 | saint-philippe
# Processing Record 36 of Set 2 | yairipok
# Processing Record 37 of Set 2 | sanchursk
# Processing Record 38 of Set 2 | sibolga
# Processing Record 39 of Set 2 | santana do livramento
# Processing Record 40 of Set 2 | lufilufi
# Processing Record 41 of Set 2 | kampot
# Processing Record 42 of Set 2 | vaini
# Processing Record 43 of Set 2 | ancud
# Processing Record 44 of Set 2 | pemangkat
# Processing Record 45 of Set 2 | namibe
# Processing Record 46 of Set 2 | saskylakh
# Processing Record 47 of Set 2 | ayan
# Processing Record 48 of Set 2 | yar-sale
# Processing Record 49 of Set 2 | trenggalek
# Processing Record 50 of Set 2 | cangzhou
# Processing Record 1 of Set 3 | masuda
# Processing Record 2 of Set 3 | ponta do sol
# Processing Record 3 of Set 3 | puerto ayora
# Processing Record 4 of Set 3 | hualmay
# Processing Record 5 of Set 3 | chake chake
# Processing Record 6 of Set 3 | isangel
# Processing Record 7 of Set 3 | punta arenas
# Processing Record 8 of Set 3 | new norfolk
# Processing Record 9 of Set 3 | balkhash
# Processing Record 10 of Set 3 | port alfred
# Processing Record 11 of Set 3 | triolet
# Processing Record 12 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 15 of Set 3 | caravelas
# Processing Record 16 of Set 3 | tucuman
# Processing Record 17 of Set 3 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 18 of Set 3 | nabire
# Processing Record 19 of Set 3 | chuy
# Processing Record 20 of Set 3 | kapaa
# Processing Record 21 of Set 3 | beyneu
# Processing Record 22 of Set 3 | kahului
# Processing Record 23 of Set 3 | airai
# Processing Record 24 of Set 3 | nago
# Processing Record 25 of Set 3 | bethel
# Processing Record 26 of Set 3 | high level
# Processing Record 27 of Set 3 | adeje
# Processing Record 28 of Set 3 | villa maria
# Processing Record 29 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 3 | pisco
# Processing Record 31 of Set 3 | provideniya
# Processing Record 32 of Set 3 | cape town
# Processing Record 33 of Set 3 | victoria
# Processing Record 34 of Set 3 | mehamn
# Processing Record 35 of Set 3 | waddan
# Processing Record 36 of Set 3 | uniontown
# Processing Record 37 of Set 3 | tasiilaq
# Processing Record 38 of Set 3 | szczecin
# Processing Record 39 of Set 3 | chokurdakh
# Processing Record 40 of Set 3 | clyde river
# Processing Record 41 of Set 3 | pedasi
# Processing Record 42 of Set 3 | teberda
# Processing Record 43 of Set 3 | kuala terengganu
# Processing Record 44 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 3 | faya
# Processing Record 46 of Set 3 | acapulco
# Processing Record 47 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 3 | dikson
# Processing Record 49 of Set 3 | sinnamary
# Processing Record 50 of Set 3 | bambous virieux
# Processing Record 1 of Set 4 | bacuit
# City not found. Skipping...
# Processing Record 2 of Set 4 | salinopolis
# Processing Record 3 of Set 4 | marsa matruh
# Processing Record 4 of Set 4 | douentza
# Processing Record 5 of Set 4 | banjar
# Processing Record 6 of Set 4 | le port
# Processing Record 7 of Set 4 | hasaki
# Processing Record 8 of Set 4 | lebedyn
# Processing Record 9 of Set 4 | mporokoso
# Processing Record 10 of Set 4 | kijang
# Processing Record 11 of Set 4 | butaritari
# Processing Record 12 of Set 4 | klaksvik
# Processing Record 13 of Set 4 | port hardy
# Processing Record 14 of Set 4 | thompson
# Processing Record 15 of Set 4 | jamame
# Processing Record 16 of Set 4 | chinhoyi
# Processing Record 17 of Set 4 | longyearbyen
# Processing Record 18 of Set 4 | bluff
# Processing Record 19 of Set 4 | rio gallegos
# Processing Record 20 of Set 4 | hambantota
# Processing Record 21 of Set 4 | praya
# Processing Record 22 of Set 4 | mayo
# Processing Record 23 of Set 4 | richards bay
# Processing Record 24 of Set 4 | qalyub
# Processing Record 25 of Set 4 | tianpeng
# Processing Record 26 of Set 4 | codrington
# Processing Record 27 of Set 4 | tazovskiy
# Processing Record 28 of Set 4 | rabo de peixe
# Processing Record 29 of Set 4 | bilma
# Processing Record 30 of Set 4 | morristown
# Processing Record 31 of Set 4 | manaus
# Processing Record 32 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 4 | altamont
# Processing Record 34 of Set 4 | preobrazheniye
# Processing Record 35 of Set 4 | marsh harbour
# Processing Record 36 of Set 4 | ojinaga
# Processing Record 37 of Set 4 | north bend
# Processing Record 38 of Set 4 | fevralsk
# City not found. Skipping...
# Processing Record 39 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 4 | georgetown
# Processing Record 42 of Set 4 | port lincoln
# Processing Record 43 of Set 4 | bathsheba
# Processing Record 44 of Set 4 | sao filipe
# Processing Record 45 of Set 4 | atambua
# Processing Record 46 of Set 4 | aykhal
# Processing Record 47 of Set 4 | zuenoula
# Processing Record 48 of Set 4 | xiuyan
# Processing Record 49 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 4 | timra
# Processing Record 1 of Set 5 | green valley
# Processing Record 2 of Set 5 | asau
# Processing Record 3 of Set 5 | tuatapere
# Processing Record 4 of Set 5 | tuy hoa
# Processing Record 5 of Set 5 | vallenar
# Processing Record 6 of Set 5 | kodiak
# Processing Record 7 of Set 5 | boende
# Processing Record 8 of Set 5 | harrow
# Processing Record 9 of Set 5 | harper
# Processing Record 10 of Set 5 | lompoc
# Processing Record 11 of Set 5 | nantucket
# Processing Record 12 of Set 5 | grand-lahou
# Processing Record 13 of Set 5 | sioux lookout
# Processing Record 14 of Set 5 | nome
# Processing Record 15 of Set 5 | sayyan
# Processing Record 16 of Set 5 | mahebourg
# Processing Record 17 of Set 5 | montbrison
# Processing Record 18 of Set 5 | haibowan
# City not found. Skipping...
# Processing Record 19 of Set 5 | saint-georges
# Processing Record 20 of Set 5 | lubao
# Processing Record 21 of Set 5 | lavrentiya
# Processing Record 22 of Set 5 | ketchikan
# Processing Record 23 of Set 5 | severo-kurilsk
# Processing Record 24 of Set 5 | manjeshwar
# Processing Record 25 of Set 5 | geraldton
# Processing Record 26 of Set 5 | laguna
# Processing Record 27 of Set 5 | naryan-mar
# Processing Record 28 of Set 5 | fortuna
# Processing Record 29 of Set 5 | murakami
# Processing Record 30 of Set 5 | stepnogorsk
# Processing Record 31 of Set 5 | lebu
# Processing Record 32 of Set 5 | camacha
# Processing Record 33 of Set 5 | doha
# Processing Record 34 of Set 5 | anadyr
# Processing Record 35 of Set 5 | ikeda
# Processing Record 36 of Set 5 | shimoda
# Processing Record 37 of Set 5 | upernavik
# Processing Record 38 of Set 5 | shiyan
# Processing Record 39 of Set 5 | srednekolymsk
# Processing Record 40 of Set 5 | ust-nera
# Processing Record 41 of Set 5 | buqayq
# City not found. Skipping...
# Processing Record 42 of Set 5 | maniitsoq
# Processing Record 43 of Set 5 | olga
# Processing Record 44 of Set 5 | palmer
# Processing Record 45 of Set 5 | kruisfontein
# Processing Record 46 of Set 5 | lorengau
# Processing Record 47 of Set 5 | zhicheng
# Processing Record 48 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 49 of Set 5 | caconda
# Processing Record 50 of Set 5 | suntar
# Processing Record 1 of Set 6 | padang
# Processing Record 2 of Set 6 | ahuimanu
# Processing Record 3 of Set 6 | yerbogachen
# Processing Record 4 of Set 6 | gemena
# Processing Record 5 of Set 6 | cabo san lucas
# Processing Record 6 of Set 6 | benghazi
# Processing Record 7 of Set 6 | shihezi
# Processing Record 8 of Set 6 | usta muhammad
# Processing Record 9 of Set 6 | luganville
# Processing Record 10 of Set 6 | oktyabrskoye
# Processing Record 11 of Set 6 | redhakhol
# City not found. Skipping...
# Processing Record 12 of Set 6 | oum hadjer
# Processing Record 13 of Set 6 | salalah
# Processing Record 14 of Set 6 | loandjili
# Processing Record 15 of Set 6 | torbay
# Processing Record 16 of Set 6 | hetauda
# Processing Record 17 of Set 6 | trelew
# Processing Record 18 of Set 6 | komsomolskiy
# Processing Record 19 of Set 6 | rovaniemi
# Processing Record 20 of Set 6 | vanino
# Processing Record 21 of Set 6 | kloulklubed
# Processing Record 22 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 6 | khasan
# Processing Record 24 of Set 6 | nelson bay
# Processing Record 25 of Set 6 | san cristobal
# Processing Record 26 of Set 6 | ahipara
# Processing Record 27 of Set 6 | adelaide
# Processing Record 28 of Set 6 | merauke
# Processing Record 29 of Set 6 | kargil
# Processing Record 30 of Set 6 | prieska
# Processing Record 31 of Set 6 | baykit
# Processing Record 32 of Set 6 | imeni poliny osipenko
# Processing Record 33 of Set 6 | carnarvon
# Processing Record 34 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 35 of Set 6 | zhigansk
# Processing Record 36 of Set 6 | calvia
# Processing Record 37 of Set 6 | havoysund
# Processing Record 38 of Set 6 | palu
# Processing Record 39 of Set 6 | lakes entrance
# Processing Record 40 of Set 6 | suleja
# Processing Record 41 of Set 6 | noumea
# Processing Record 42 of Set 6 | shingu
# Processing Record 43 of Set 6 | cayenne
# Processing Record 44 of Set 6 | lagoa
# Processing Record 45 of Set 6 | korla
# Processing Record 46 of Set 6 | aksarka
# Processing Record 47 of Set 6 | balabac
# Processing Record 48 of Set 6 | santa rita do sapucai
# Processing Record 49 of Set 6 | saint-augustin
# Processing Record 50 of Set 6 | birjand
# Processing Record 1 of Set 7 | rafraf
# Processing Record 2 of Set 7 | bend
# Processing Record 3 of Set 7 | huarmey
# Processing Record 4 of Set 7 | dhidhdhoo
# Processing Record 5 of Set 7 | san jose
# Processing Record 6 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 7 of Set 7 | east london
# Processing Record 8 of Set 7 | akhaldaba
# Processing Record 9 of Set 7 | inongo
# Processing Record 10 of Set 7 | cherskiy
# Processing Record 11 of Set 7 | vylgort
# City not found. Skipping...
# Processing Record 12 of Set 7 | mar del plata
# Processing Record 13 of Set 7 | kiunga
# Processing Record 14 of Set 7 | kurgan
# Processing Record 15 of Set 7 | saint pete beach
# Processing Record 16 of Set 7 | bouna
# Processing Record 17 of Set 7 | haines junction
# Processing Record 18 of Set 7 | buala
# Processing Record 19 of Set 7 | urengoy
# Processing Record 20 of Set 7 | mill valley
# Processing Record 21 of Set 7 | baberu
# Processing Record 22 of Set 7 | kavaratti
# Processing Record 23 of Set 7 | vila velha
# Processing Record 24 of Set 7 | grindavik
# Processing Record 25 of Set 7 | huntsville
# Processing Record 26 of Set 7 | leningradskiy
# Processing Record 27 of Set 7 | norman wells
# Processing Record 28 of Set 7 | zephyrhills
# Processing Record 29 of Set 7 | nikolskoye
# Processing Record 30 of Set 7 | katsuura
# Processing Record 31 of Set 7 | zhangjiakou
# Processing Record 32 of Set 7 | ylojarvi
# Processing Record 33 of Set 7 | yulara
# Processing Record 34 of Set 7 | jonkoping
# Processing Record 35 of Set 7 | arraial do cabo
# Processing Record 36 of Set 7 | port elizabeth
# Processing Record 37 of Set 7 | brae
# Processing Record 38 of Set 7 | saint anthony
# Processing Record 39 of Set 7 | caceres
# Processing Record 40 of Set 7 | puerto gaitan
# Processing Record 41 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 7 | port macquarie
# Processing Record 43 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 7 | bonavista
# Processing Record 45 of Set 7 | kuytun
# Processing Record 46 of Set 7 | ippy
# Processing Record 47 of Set 7 | middle island
# Processing Record 48 of Set 7 | doos
# Processing Record 49 of Set 7 | kudahuvadhoo
# Processing Record 50 of Set 7 | necochea
# Processing Record 1 of Set 8 | buriti dos lopes
# Processing Record 2 of Set 8 | hornepayne
# Processing Record 3 of Set 8 | port moresby
# Processing Record 4 of Set 8 | rocha
# Processing Record 5 of Set 8 | faanui
# Processing Record 6 of Set 8 | kashi
# Processing Record 7 of Set 8 | luderitz
# Processing Record 8 of Set 8 | khatanga
# Processing Record 9 of Set 8 | liverpool
# Processing Record 10 of Set 8 | bengkulu
# Processing Record 11 of Set 8 | englewood
# Processing Record 12 of Set 8 | broome
# Processing Record 13 of Set 8 | tupik
# Processing Record 14 of Set 8 | mattru
# Processing Record 15 of Set 8 | beringovskiy
# Processing Record 16 of Set 8 | umm lajj
# Processing Record 17 of Set 8 | hami
# Processing Record 18 of Set 8 | whitianga
# Processing Record 19 of Set 8 | puerto baquerizo moreno
# Processing Record 20 of Set 8 | sabha
# Processing Record 21 of Set 8 | takoradi
# Processing Record 22 of Set 8 | ismailia
# Processing Record 23 of Set 8 | maceio
# Processing Record 24 of Set 8 | misratah
# Processing Record 25 of Set 8 | seoul
# Processing Record 26 of Set 8 | durant
# Processing Record 27 of Set 8 | iqaluit
# Processing Record 28 of Set 8 | xinzhi
# Processing Record 29 of Set 8 | coahuayana
# Processing Record 30 of Set 8 | vodnyy
# Processing Record 31 of Set 8 | nagato
# Processing Record 32 of Set 8 | sorland
# Processing Record 33 of Set 8 | fort nelson
# Processing Record 34 of Set 8 | carballo
# Processing Record 35 of Set 8 | comodoro rivadavia
# Processing Record 36 of Set 8 | tongzi
# Processing Record 37 of Set 8 | sri aman
# Processing Record 38 of Set 8 | tessalit
# Processing Record 39 of Set 8 | kasempa
# Processing Record 40 of Set 8 | hofn
# Processing Record 41 of Set 8 | mugur-aksy
# Processing Record 42 of Set 8 | duluth
# Processing Record 43 of Set 8 | groton
# Processing Record 44 of Set 8 | tahta
# Processing Record 45 of Set 8 | vesoul
# Processing Record 46 of Set 8 | temax
# Processing Record 47 of Set 8 | husavik
# Processing Record 48 of Set 8 | san quintin
# Processing Record 49 of Set 8 | morondava
# Processing Record 50 of Set 8 | roebourne
# Processing Record 1 of Set 9 | linjiang
# Processing Record 2 of Set 9 | poyarkovo
# Processing Record 3 of Set 9 | half moon bay
# Processing Record 4 of Set 9 | aojiang
# Processing Record 5 of Set 9 | ganta
# Processing Record 6 of Set 9 | hegang
# Processing Record 7 of Set 9 | salym
# Processing Record 8 of Set 9 | kefamenanu
# Processing Record 9 of Set 9 | shadrinsk
# Processing Record 10 of Set 9 | kalaleh
# Processing Record 11 of Set 9 | carmen
# Processing Record 12 of Set 9 | adre
# Processing Record 13 of Set 9 | teguise
# Processing Record 14 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 9 | pacific grove
# Processing Record 16 of Set 9 | buin
# Processing Record 17 of Set 9 | olafsvik
# Processing Record 18 of Set 9 | gushikawa
# Processing Record 19 of Set 9 | puerto montt
# Processing Record 20 of Set 9 | saint-pierre
# Processing Record 21 of Set 9 | labuhan
# Processing Record 22 of Set 9 | lichinga
# Processing Record 23 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 9 | hobyo
# Processing Record 25 of Set 9 | kulhudhuffushi
# Processing Record 26 of Set 9 | vao
# Processing Record 27 of Set 9 | tezu
# Processing Record 28 of Set 9 | vanimo
# Processing Record 29 of Set 9 | molchanovo
# Processing Record 30 of Set 9 | sinkat
# City not found. Skipping...
# Processing Record 31 of Set 9 | sechura
# Processing Record 32 of Set 9 | ust-maya
# Processing Record 33 of Set 9 | masvingo
# Processing Record 34 of Set 9 | tiznit
# Processing Record 35 of Set 9 | betanzos
# Processing Record 36 of Set 9 | pahrump
# Processing Record 37 of Set 9 | sukhumi
# Processing Record 38 of Set 9 | santa vitoria do palmar
# Processing Record 39 of Set 9 | aswan
# Processing Record 40 of Set 9 | longhua
# Processing Record 41 of Set 9 | ramjibanpur
# Processing Record 42 of Set 9 | maymanak
# City not found. Skipping...
# Processing Record 43 of Set 9 | yenagoa
# Processing Record 44 of Set 9 | ampanihy
# Processing Record 45 of Set 9 | la asuncion
# Processing Record 46 of Set 9 | pandan
# Processing Record 47 of Set 9 | krasnogvardeyskiy
# Processing Record 48 of Set 9 | vondrozo
# Processing Record 49 of Set 9 | chapais
# Processing Record 50 of Set 9 | landskrona
# Processing Record 1 of Set 10 | sorong
# Processing Record 2 of Set 10 | narsaq
# Processing Record 3 of Set 10 | jiangyou
# Processing Record 4 of Set 10 | vihari
# Processing Record 5 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 10 | riyadh
# Processing Record 7 of Set 10 | verkhoyansk
# Processing Record 8 of Set 10 | luoyang
# Processing Record 9 of Set 10 | visnes
# Processing Record 10 of Set 10 | cumanayagua
# Processing Record 11 of Set 10 | san andres
# Processing Record 12 of Set 10 | hailar
# Processing Record 13 of Set 10 | svetlogorsk
# Processing Record 14 of Set 10 | shakawe
# Processing Record 15 of Set 10 | lebanon
# Processing Record 16 of Set 10 | touros
# Processing Record 17 of Set 10 | balao
# Processing Record 18 of Set 10 | barentu
# Processing Record 19 of Set 10 | los llanos de aridane
# Processing Record 20 of Set 10 | berlevag
# Processing Record 21 of Set 10 | ilulissat
# Processing Record 22 of Set 10 | grand gaube
# Processing Record 23 of Set 10 | garissa
# Processing Record 24 of Set 10 | rudnichnyy
# Processing Record 25 of Set 10 | ingham
# Processing Record 26 of Set 10 | yumen
# Processing Record 27 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 28 of Set 10 | sabla
# Processing Record 29 of Set 10 | tutoia
# Processing Record 30 of Set 10 | shitkino
# Processing Record 31 of Set 10 | kupino
# Processing Record 32 of Set 10 | santa flavia
# Processing Record 33 of Set 10 | sosnogorsk
# Processing Record 34 of Set 10 | minab
# Processing Record 35 of Set 10 | kongolo
# Processing Record 36 of Set 10 | kununurra
# Processing Record 37 of Set 10 | mataram
# Processing Record 38 of Set 10 | akdepe
# Processing Record 39 of Set 10 | palmeira das missoes
# Processing Record 40 of Set 10 | adrar
# Processing Record 41 of Set 10 | sendhwa
# Processing Record 42 of Set 10 | mareeba
# Processing Record 43 of Set 10 | nizwa
# Processing Record 44 of Set 10 | manicore
# Processing Record 45 of Set 10 | sawtell
# Processing Record 46 of Set 10 | mongo
# Processing Record 47 of Set 10 | makaryev
# Processing Record 48 of Set 10 | aklavik
# Processing Record 49 of Set 10 | westport
# Processing Record 50 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 11 | pundaguitan
# Processing Record 2 of Set 11 | capreol
# Processing Record 3 of Set 11 | auki
# Processing Record 4 of Set 11 | oranjemund
# Processing Record 5 of Set 11 | shitanjing
# Processing Record 6 of Set 11 | kirakira
# Processing Record 7 of Set 11 | port hedland
# Processing Record 8 of Set 11 | huancabamba
# Processing Record 9 of Set 11 | pevek
# Processing Record 10 of Set 11 | betsiamites
# Processing Record 11 of Set 11 | salinas
# Processing Record 12 of Set 11 | ilo
# Processing Record 13 of Set 11 | bonthe
# Processing Record 14 of Set 11 | poso
# Processing Record 15 of Set 11 | topolovatu mare
# Processing Record 16 of Set 11 | mongomo
# Processing Record 17 of Set 11 | dongsheng
# Processing Record 18 of Set 11 | mountain home
# Processing Record 19 of Set 11 | flin flon
# Processing Record 20 of Set 11 | neuquen
# Processing Record 21 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 22 of Set 11 | maykain
# City not found. Skipping...
# Processing Record 23 of Set 11 | tsiroanomandidy
# Processing Record 24 of Set 11 | san pedro
# Processing Record 25 of Set 11 | okha
# Processing Record 26 of Set 11 | yeppoon
# Processing Record 27 of Set 11 | constitucion
# Processing Record 28 of Set 11 | nakusp
# Processing Record 29 of Set 11 | aripuana
# Processing Record 30 of Set 11 | tura
# Processing Record 31 of Set 11 | ossora
# Processing Record 32 of Set 11 | tailai
# Processing Record 33 of Set 11 | inhambane
# Processing Record 34 of Set 11 | baruun-urt
# Processing Record 35 of Set 11 | shelopugino
# Processing Record 36 of Set 11 | svetlyy
# Processing Record 37 of Set 11 | tungor
# Processing Record 38 of Set 11 | the valley
# Processing Record 39 of Set 11 | denpasar
# Processing Record 40 of Set 11 | sao joao da barra
# Processing Record 41 of Set 11 | lata
# Processing Record 42 of Set 11 | trincomalee
# Processing Record 43 of Set 11 | antalaha
# Processing Record 44 of Set 11 | duz
# City not found. Skipping...
# Processing Record 45 of Set 11 | nanortalik
# Processing Record 46 of Set 11 | tazmalt
# Processing Record 47 of Set 11 | evensk
# Processing Record 48 of Set 11 | mabaruma
# Processing Record 49 of Set 11 | mumford
# Processing Record 50 of Set 11 | ambulu
# Processing Record 1 of Set 12 | bismarck
# Processing Record 2 of Set 12 | sobolevo
# Processing Record 3 of Set 12 | bo
# City not found. Skipping...
# Processing Record 4 of Set 12 | mouzouras
# Processing Record 5 of Set 12 | dunbar
# Processing Record 6 of Set 12 | merritt
# Processing Record 7 of Set 12 | miyako
# Processing Record 8 of Set 12 | puente grande
# Processing Record 9 of Set 12 | olinda
# Processing Record 10 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 11 of Set 12 | togur
# Processing Record 12 of Set 12 | talara
# Processing Record 13 of Set 12 | egvekinot
# Processing Record 14 of Set 12 | okhotsk
# Processing Record 15 of Set 12 | muzhi
# Processing Record 16 of Set 12 | bela
# Processing Record 17 of Set 12 | bambanglipuro
# Processing Record 18 of Set 12 | berdigestyakh
# Processing Record 19 of Set 12 | zhezkazgan
# Processing Record 20 of Set 12 | sur
# Processing Record 21 of Set 12 | turayf
# Processing Record 22 of Set 12 | champerico
# Processing Record 23 of Set 12 | saiha
# Processing Record 24 of Set 12 | khairabad
# Processing Record 25 of Set 12 | mayumba
# Processing Record 26 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 12 | willowmore
# Processing Record 28 of Set 12 | siuna
# Processing Record 29 of Set 12 | price
# Processing Record 30 of Set 12 | culpeper
# Processing Record 31 of Set 12 | turukhansk
# Processing Record 32 of Set 12 | maykor
# Processing Record 33 of Set 12 | lashio
# Processing Record 34 of Set 12 | peniche
# Processing Record 35 of Set 12 | chifeng
# Processing Record 36 of Set 12 | kapiri mposhi
# Processing Record 37 of Set 12 | atamanovka
# Processing Record 38 of Set 12 | bathurst
# Processing Record 39 of Set 12 | lindi
# Processing Record 40 of Set 12 | sambava
# Processing Record 41 of Set 12 | soyo
# Processing Record 42 of Set 12 | pitimbu
# Processing Record 43 of Set 12 | great yarmouth
# Processing Record 44 of Set 12 | kawalu
# Processing Record 45 of Set 12 | piacabucu
# Processing Record 46 of Set 12 | nishihara
# Processing Record 47 of Set 12 | sevierville
# Processing Record 48 of Set 12 | ksenyevka
# City not found. Skipping...
# Processing Record 49 of Set 12 | krasnystaw
# Processing Record 50 of Set 12 | souillac
# Processing Record 1 of Set 13 | nouadhibou
# Processing Record 2 of Set 13 | banos
# Processing Record 3 of Set 13 | mirabad
# Processing Record 4 of Set 13 | college
# Processing Record 5 of Set 13 | bartica
# Processing Record 6 of Set 13 | wajir
# Processing Record 7 of Set 13 | zyryanskoye
# Processing Record 8 of Set 13 | waynesboro
# Processing Record 9 of Set 13 | dharampur
# Processing Record 10 of Set 13 | karakendzha
# City not found. Skipping...
# Processing Record 11 of Set 13 | kapit
# Processing Record 12 of Set 13 | velika gorica
# Processing Record 13 of Set 13 | suao
# City not found. Skipping...
# Processing Record 14 of Set 13 | uvinza
# Processing Record 15 of Set 13 | suluq
# Processing Record 16 of Set 13 | nerchinskiy zavod
# Processing Record 17 of Set 13 | parrita
# Processing Record 18 of Set 13 | tiksi
# Processing Record 19 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 20 of Set 13 | bukachacha
# Processing Record 21 of Set 13 | nyurba
# Processing Record 22 of Set 13 | emba
# Processing Record 23 of Set 13 | les cayes
# Processing Record 24 of Set 13 | sola
# Processing Record 25 of Set 13 | yaan
# Processing Record 26 of Set 13 | sao desiderio
# Processing Record 27 of Set 13 | flinders
# Processing Record 28 of Set 13 | sterling
# Processing Record 29 of Set 13 | wladyslawowo
# Processing Record 30 of Set 13 | krasnovishersk
# Processing Record 31 of Set 13 | dillon
# Processing Record 32 of Set 13 | teruel
# Processing Record 33 of Set 13 | atar
# Processing Record 34 of Set 13 | nacala
# Processing Record 35 of Set 13 | kutum
# Processing Record 36 of Set 13 | gracac
# Processing Record 37 of Set 13 | portland
# Processing Record 38 of Set 13 | klyuchevskiy
# Processing Record 39 of Set 13 | matamoros
# Processing Record 40 of Set 13 | zalantun
# Processing Record 41 of Set 13 | north platte
# Processing Record 42 of Set 13 | sanok
# Processing Record 43 of Set 13 | chitral
# Processing Record 44 of Set 13 | brandfort
# Processing Record 45 of Set 13 | arrecife
# Processing Record 46 of Set 13 | oistins
# Processing Record 47 of Set 13 | vorobyevka
# Processing Record 48 of Set 13 | zhangye
# Processing Record 49 of Set 13 | ringkobing
# Processing Record 50 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 1 of Set 14 | sao jose da coroa grande
# Processing Record 2 of Set 14 | port-cartier
# Processing Record 3 of Set 14 | santa maria
# Processing Record 4 of Set 14 | imbituba
# Processing Record 5 of Set 14 | baiyin
# Processing Record 6 of Set 14 | alice springs
# Processing Record 7 of Set 14 | la ronge
# Processing Record 8 of Set 14 | bridlington
# Processing Record 9 of Set 14 | swan hill
# Processing Record 10 of Set 14 | grakhovo
# Processing Record 11 of Set 14 | mozarlandia
# Processing Record 12 of Set 14 | clinton
# Processing Record 13 of Set 14 | smithers
# Processing Record 14 of Set 14 | beloha
# Processing Record 15 of Set 14 | moron
# Processing Record 16 of Set 14 | syracuse
# Processing Record 17 of Set 14 | nueva gerona
# Processing Record 18 of Set 14 | humaita
# Processing Record 19 of Set 14 | rio grande
# Processing Record 20 of Set 14 | valday
# Processing Record 21 of Set 14 | arroyo
# Processing Record 22 of Set 14 | redencao
# Processing Record 23 of Set 14 | ursulo galvan
# Processing Record 24 of Set 14 | lac du bonnet
# Processing Record 25 of Set 14 | tuggurt
# City not found. Skipping...
# Processing Record 26 of Set 14 | goderich
# Processing Record 27 of Set 14 | seaforth
# Processing Record 28 of Set 14 | chegdomyn
# Processing Record 29 of Set 14 | sidi ali
# Processing Record 30 of Set 14 | severo-yeniseyskiy
# Processing Record 31 of Set 14 | sistranda
# Processing Record 32 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 33 of Set 14 | sao francisco de assis
# Processing Record 34 of Set 14 | garwa
# Processing Record 35 of Set 14 | saeby
# Processing Record 36 of Set 14 | saint-joseph
# Processing Record 37 of Set 14 | atyashevo
# Processing Record 38 of Set 14 | dinan
# Processing Record 39 of Set 14 | havelock
# Processing Record 40 of Set 14 | whitehorse
# Processing Record 41 of Set 14 | northam
# Processing Record 42 of Set 14 | marawi
# Processing Record 43 of Set 14 | general roca
# Processing Record 44 of Set 14 | billings
# Processing Record 45 of Set 14 | san vicente
# Processing Record 46 of Set 14 | lastoursville
# Processing Record 47 of Set 14 | a
# City not found. Skipping...
# Processing Record 48 of Set 14 | road town
# Processing Record 49 of Set 14 | bereda
# Processing Record 50 of Set 14 | muzquiz
# City not found. Skipping...
# Processing Record 1 of Set 15 | marzuq
# Processing Record 2 of Set 15 | brownsville
# Processing Record 3 of Set 15 | pailon
# Processing Record 4 of Set 15 | scottsbluff
# Processing Record 5 of Set 15 | temaraia
# City not found. Skipping...
# Processing Record 6 of Set 15 | sturgis
# Processing Record 7 of Set 15 | kenai
# Processing Record 8 of Set 15 | cockburn town
# Processing Record 9 of Set 15 | kaseda
# Processing Record 10 of Set 15 | darhan
# Processing Record 11 of Set 15 | potgietersrus
# City not found. Skipping...
# Processing Record 12 of Set 15 | yakeshi
# Processing Record 13 of Set 15 | morelia
# Processing Record 14 of Set 15 | eyl
# Processing Record 15 of Set 15 | pangnirtung
# Processing Record 16 of Set 15 | bodden town
# Processing Record 17 of Set 15 | maldonado
# Processing Record 18 of Set 15 | suseni
# Processing Record 19 of Set 15 | mezen
# Processing Record 20 of Set 15 | carutapera
# Processing Record 21 of Set 15 | sakakah
# Processing Record 22 of Set 15 | kiama
# Processing Record 23 of Set 15 | magadan
# Processing Record 24 of Set 15 | khor
# Processing Record 25 of Set 15 | mao
# Processing Record 26 of Set 15 | kaveripattinam
# Processing Record 27 of Set 15 | carauari
# Processing Record 28 of Set 15 | bhatkal
# Processing Record 29 of Set 15 | quatre cocos
# Processing Record 30 of Set 15 | maniwaki
# Processing Record 31 of Set 15 | ambon
# Processing Record 32 of Set 15 | tuscaloosa
# Processing Record 33 of Set 15 | jackson
# Processing Record 34 of Set 15 | borsad
# Processing Record 35 of Set 15 | biak
# Processing Record 36 of Set 15 | drovyanaya
# Processing Record 37 of Set 15 | bilibino
# Processing Record 38 of Set 15 | wanning
# Processing Record 39 of Set 15 | pasaje
# Processing Record 40 of Set 15 | riviere-au-renard
# Processing Record 41 of Set 15 | bardiyah
# Processing Record 42 of Set 15 | beidao
# Processing Record 43 of Set 15 | vermilion
# Processing Record 44 of Set 15 | sept-iles
# Processing Record 45 of Set 15 | paraiso
# Processing Record 46 of Set 15 | sai buri
# Processing Record 47 of Set 15 | yakshur-bodya
# City not found. Skipping...
# Processing Record 48 of Set 15 | naliya
# Processing Record 49 of Set 15 | kalanguy
# Processing Record 50 of Set 15 | pringsewu
# Processing Record 1 of Set 16 | phan rang
# City not found. Skipping...
# Processing Record 2 of Set 16 | fairbanks
# Processing Record 3 of Set 16 | weihe
# Processing Record 4 of Set 16 | malanville
# Processing Record 5 of Set 16 | bose
# Processing Record 6 of Set 16 | belaya gora
# Processing Record 7 of Set 16 | kuching
# Processing Record 8 of Set 16 | pionerskiy
# Processing Record 9 of Set 16 | nemuro
# Processing Record 10 of Set 16 | del rio
# Processing Record 11 of Set 16 | snezhnogorsk
# Processing Record 12 of Set 16 | lima
# Processing Record 13 of Set 16 | codajas
# Processing Record 14 of Set 16 | dabat
# Processing Record 15 of Set 16 | neyshabur
# Processing Record 16 of Set 16 | port shepstone
# Processing Record 17 of Set 16 | khlevnoye
# Processing Record 18 of Set 16 | tashla
# Processing Record 19 of Set 16 | marshall
# Processing Record 20 of Set 16 | coruripe
# Processing Record 21 of Set 16 | masuguru
# Processing Record 22 of Set 16 | zhigalovo
# Processing Record 23 of Set 16 | awbari
# Processing Record 24 of Set 16 | talas
# Processing Record 25 of Set 16 | alyangula
# Processing Record 26 of Set 16 | sarkand
# Processing Record 27 of Set 16 | luwuk
# Processing Record 28 of Set 16 | nam tha
# City not found. Skipping...
# Processing Record 29 of Set 16 | ulladulla
# Processing Record 30 of Set 16 | hurghada
# Processing Record 31 of Set 16 | eirunepe
# Processing Record 32 of Set 16 | menongue
# Processing Record 33 of Set 16 | seaford
# Processing Record 34 of Set 16 | abakaliki
# Processing Record 35 of Set 16 | emerald
# Processing Record 36 of Set 16 | butka
# Processing Record 37 of Set 16 | mae chan
# Processing Record 38 of Set 16 | kelvington
# Processing Record 39 of Set 16 | dudinka
# Processing Record 40 of Set 16 | acarau
# Processing Record 41 of Set 16 | kobayashi
# Processing Record 42 of Set 16 | poum
# Processing Record 43 of Set 16 | neiafu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Coquimbo      CL -29.9533  -71.3436     62.33        72           0
# 1    Dickinson      US  29.4608  -95.0513     89.13        50           0
# 2         Naze      JP  28.3667  129.4833     72.52        85          95
# 3       Porvoo      FI  60.3923   25.6651     48.24        95           7
# 4  Oktyabrskiy      RU  54.4815   53.4710     49.59        67         100
#
#    Wind Speed City Description
# 0       13.80        clear sky
# 1       11.50        clear sky
# 2        2.64  overcast clouds
# 3        8.10        clear sky
# 4        5.46  overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
